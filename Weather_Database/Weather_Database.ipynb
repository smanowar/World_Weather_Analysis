# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
config="../../config.py"
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #parse the data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | rapid valley
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | beruwala
# Processing Record 9 of Set 1 | malkapur
# Processing Record 10 of Set 1 | yenagoa
# Processing Record 11 of Set 1 | kloulklubed
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | marrakesh
# Processing Record 15 of Set 1 | nemuro
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | astana
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | morros
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | rantauprapat
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | la paz
# Processing Record 31 of Set 1 | ixtapa
# Processing Record 32 of Set 1 | laguna
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | baykit
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | kampene
# Processing Record 40 of Set 1 | aguimes
# Processing Record 41 of Set 1 | thinadhoo
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | burns lake
# Processing Record 44 of Set 1 | deputatskiy
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | prainha
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | loandjili
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | fairlie
# Processing Record 1 of Set 2 | tulun
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | olinda
# Processing Record 5 of Set 2 | zlynka
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 2 | bandarbeyla
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | pacific grove
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | newberry
# Processing Record 13 of Set 2 | setermoen
# Processing Record 14 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | vaitape
# Processing Record 17 of Set 2 | katubao
# Processing Record 18 of Set 2 | vermilion
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | ugoofaaru
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | luwuk
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | shingu
# Processing Record 26 of Set 2 | mokhsogollokh
# Processing Record 27 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 2 | sonoita
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | zhigansk
# Processing Record 31 of Set 2 | samarai
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | ukiah
# Processing Record 35 of Set 2 | labuhan
# Processing Record 36 of Set 2 | port hardy
# Processing Record 37 of Set 2 | avera
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | quatre cocos
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | novoagansk
# Processing Record 46 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 2 | codajas
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | vao
# Processing Record 1 of Set 3 | prado
# Processing Record 2 of Set 3 | asau
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | pinega
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | three hills
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | polunochnoye
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 3 | atocha
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | sobolevo
# Processing Record 20 of Set 3 | sorland
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | saint-francois
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | fairbanks
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | hualmay
# Processing Record 27 of Set 3 | shakawe
# Processing Record 28 of Set 3 | the pas
# Processing Record 29 of Set 3 | billings
# Processing Record 30 of Set 3 | brokopondo
# Processing Record 31 of Set 3 | tilichiki
# Processing Record 32 of Set 3 | vestmannaeyjar
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | ptuj
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | juneau
# Processing Record 37 of Set 3 | batagay-alyta
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | manggar
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | petionville
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | chicama
# Processing Record 44 of Set 3 | mogadishu
# Processing Record 45 of Set 3 | gao
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | carutapera
# Processing Record 49 of Set 3 | raudeberg
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | damghan
# Processing Record 2 of Set 4 | samana
# Processing Record 3 of Set 4 | maniitsoq
# Processing Record 4 of Set 4 | bollnas
# Processing Record 5 of Set 4 | karatuzskoye
# Processing Record 6 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 4 | cap malheureux
# Processing Record 8 of Set 4 | balkhash
# Processing Record 9 of Set 4 | korla
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | tonekabon
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | kailua
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | oranjemund
# Processing Record 19 of Set 4 | la sarre
# Processing Record 20 of Set 4 | novikovo
# Processing Record 21 of Set 4 | harnosand
# Processing Record 22 of Set 4 | yasothon
# Processing Record 23 of Set 4 | maldonado
# Processing Record 24 of Set 4 | qianan
# Processing Record 25 of Set 4 | beringovskiy
# Processing Record 26 of Set 4 | port-cartier
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | arona
# Processing Record 30 of Set 4 | san francisco del mar
# Processing Record 31 of Set 4 | nsanje
# Processing Record 32 of Set 4 | teya
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | corn island
# Processing Record 35 of Set 4 | champerico
# Processing Record 36 of Set 4 | butaritari
# Processing Record 37 of Set 4 | chifeng
# Processing Record 38 of Set 4 | poum
# Processing Record 39 of Set 4 | tecoanapa
# Processing Record 40 of Set 4 | bandar-e lengeh
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | bereda
# Processing Record 43 of Set 4 | santa luzia
# Processing Record 44 of Set 4 | batagay
# Processing Record 45 of Set 4 | graaff-reinet
# Processing Record 46 of Set 4 | faanui
# Processing Record 47 of Set 4 | tautira
# Processing Record 48 of Set 4 | bluff
# Processing Record 49 of Set 4 | fukue
# Processing Record 50 of Set 4 | abu dhabi
# Processing Record 1 of Set 5 | villa carlos paz
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | spornoye
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | santa cruz
# Processing Record 6 of Set 5 | moose factory
# Processing Record 7 of Set 5 | livingston
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 5 | marfino
# Processing Record 12 of Set 5 | seoul
# Processing Record 13 of Set 5 | rio grande
# Processing Record 14 of Set 5 | kungurtug
# Processing Record 15 of Set 5 | kununurra
# Processing Record 16 of Set 5 | kiunga
# Processing Record 17 of Set 5 | udachnyy
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 20 of Set 5 | kijang
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | cockburn town
# Processing Record 24 of Set 5 | arlit
# Processing Record 25 of Set 5 | margate
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | visnes
# Processing Record 30 of Set 5 | rosarito
# Processing Record 31 of Set 5 | turkan
# Processing Record 32 of Set 5 | khawhai
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | solnechnyy
# Processing Record 35 of Set 5 | dubbo
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | opuwo
# Processing Record 41 of Set 5 | hovd
# Processing Record 42 of Set 5 | daru
# Processing Record 43 of Set 5 | katangli
# Processing Record 44 of Set 5 | lorengau
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | kirakira
# Processing Record 47 of Set 5 | geraldton
# Processing Record 48 of Set 5 | buta
# Processing Record 49 of Set 5 | san vicente
# Processing Record 50 of Set 5 | sorochinsk
# Processing Record 1 of Set 6 | ampanihy
# Processing Record 2 of Set 6 | ribeira grande
# Processing Record 3 of Set 6 | grand-lahou
# Processing Record 4 of Set 6 | brae
# Processing Record 5 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 6 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 7 of Set 6 | kaifeng
# Processing Record 8 of Set 6 | ionia
# Processing Record 9 of Set 6 | patea
# Processing Record 10 of Set 6 | kruisfontein
# Processing Record 11 of Set 6 | acapulco
# Processing Record 12 of Set 6 | taketa
# Processing Record 13 of Set 6 | inhambane
# Processing Record 14 of Set 6 | kuandian
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | mount gambier
# Processing Record 17 of Set 6 | byron bay
# Processing Record 18 of Set 6 | karaton
# Processing Record 19 of Set 6 | matay
# Processing Record 20 of Set 6 | kavieng
# Processing Record 21 of Set 6 | kilindoni
# Processing Record 22 of Set 6 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | manjacaze
# Processing Record 26 of Set 6 | kahului
# Processing Record 27 of Set 6 | edd
# Processing Record 28 of Set 6 | saint-joseph
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | teguldet
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | batsfjord
# Processing Record 33 of Set 6 | lompoc
# Processing Record 34 of Set 6 | calexico
# Processing Record 35 of Set 6 | morondava
# Processing Record 36 of Set 6 | cassilandia
# Processing Record 37 of Set 6 | erenhot
# Processing Record 38 of Set 6 | richards bay
# Processing Record 39 of Set 6 | rocha
# Processing Record 40 of Set 6 | whitehorse
# Processing Record 41 of Set 6 | hamilton
# Processing Record 42 of Set 6 | saint george
# Processing Record 43 of Set 6 | tillabery
# City not found. Skipping...
# Processing Record 44 of Set 6 | pangnirtung
# Processing Record 45 of Set 6 | saint-augustin
# Processing Record 46 of Set 6 | cartagena
# Processing Record 47 of Set 6 | pauini
# Processing Record 48 of Set 6 | kazachinskoye
# Processing Record 49 of Set 6 | skjervoy
# Processing Record 50 of Set 6 | pundri
# Processing Record 1 of Set 7 | curiti
# Processing Record 2 of Set 7 | aranos
# Processing Record 3 of Set 7 | souillac
# Processing Record 4 of Set 7 | silver city
# Processing Record 5 of Set 7 | bowen
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | alakurtti
# Processing Record 8 of Set 7 | chapada dos guimaraes
# Processing Record 9 of Set 7 | sao jose da coroa grande
# Processing Record 10 of Set 7 | virginia beach
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | tezu
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | camacha
# Processing Record 15 of Set 7 | berlevag
# Processing Record 16 of Set 7 | adrar
# Processing Record 17 of Set 7 | christchurch
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | yerbogachen
# Processing Record 20 of Set 7 | isla vista
# Processing Record 21 of Set 7 | hearst
# Processing Record 22 of Set 7 | rumonge
# Processing Record 23 of Set 7 | zambezi
# Processing Record 24 of Set 7 | xining
# Processing Record 25 of Set 7 | kenai
# Processing Record 26 of Set 7 | aden
# Processing Record 27 of Set 7 | fukuma
# Processing Record 28 of Set 7 | wuwei
# Processing Record 29 of Set 7 | rudnogorsk
# Processing Record 30 of Set 7 | aguada de pasajeros
# Processing Record 31 of Set 7 | haines junction
# Processing Record 32 of Set 7 | gamba
# Processing Record 33 of Set 7 | faya
# Processing Record 34 of Set 7 | cozumel
# Processing Record 35 of Set 7 | kindu
# Processing Record 36 of Set 7 | kieta
# Processing Record 37 of Set 7 | rio gallegos
# Processing Record 38 of Set 7 | coquimbo
# Processing Record 39 of Set 7 | kingman
# Processing Record 40 of Set 7 | candolim
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | lac-megantic
# Processing Record 43 of Set 7 | gayeri
# Processing Record 44 of Set 7 | matagami
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | toora-khem
# Processing Record 47 of Set 7 | pangkalanbuun
# Processing Record 48 of Set 7 | okitipupa
# Processing Record 49 of Set 7 | denpasar
# Processing Record 50 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 8 | grand gaube
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | nha trang
# Processing Record 4 of Set 8 | barguzin
# Processing Record 5 of Set 8 | half moon bay
# Processing Record 6 of Set 8 | roma
# Processing Record 7 of Set 8 | copiapo
# Processing Record 8 of Set 8 | vanavara
# Processing Record 9 of Set 8 | abha
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | maragogi
# Processing Record 12 of Set 8 | starosubkhangulovo
# Processing Record 13 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 15 of Set 8 | aklavik
# Processing Record 16 of Set 8 | nakonde
# Processing Record 17 of Set 8 | aksarka
# Processing Record 18 of Set 8 | channel-port aux basques
# Processing Record 19 of Set 8 | progreso
# Processing Record 20 of Set 8 | lamar
# Processing Record 21 of Set 8 | kaspiyskiy
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | owo
# Processing Record 24 of Set 8 | roswell
# Processing Record 25 of Set 8 | hambantota
# Processing Record 26 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | staszow
# Processing Record 30 of Set 8 | merauke
# Processing Record 31 of Set 8 | rundu
# Processing Record 32 of Set 8 | praia da vitoria
# Processing Record 33 of Set 8 | crotone
# Processing Record 34 of Set 8 | esperance
# Processing Record 35 of Set 8 | provideniya
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | kamenka
# Processing Record 38 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 8 | blagoyevo
# Processing Record 40 of Set 8 | mlowo
# Processing Record 41 of Set 8 | pombia
# Processing Record 42 of Set 8 | padang
# Processing Record 43 of Set 8 | mehamn
# Processing Record 44 of Set 8 | bonavista
# Processing Record 45 of Set 8 | sindi
# Processing Record 46 of Set 8 | oksfjord
# Processing Record 47 of Set 8 | wanning
# Processing Record 48 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | sarai
# Processing Record 1 of Set 9 | pyay
# Processing Record 2 of Set 9 | prince rupert
# Processing Record 3 of Set 9 | kolyvan
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | davidson
# Processing Record 6 of Set 9 | nouadhibou
# Processing Record 7 of Set 9 | strezhevoy
# Processing Record 8 of Set 9 | shenyang
# Processing Record 9 of Set 9 | xuddur
# Processing Record 10 of Set 9 | bedong
# Processing Record 11 of Set 9 | natal
# Processing Record 12 of Set 9 | ilabaya
# Processing Record 13 of Set 9 | ternate
# Processing Record 14 of Set 9 | kambam
# Processing Record 15 of Set 9 | sabha
# Processing Record 16 of Set 9 | mgandu
# Processing Record 17 of Set 9 | belmonte
# Processing Record 18 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 19 of Set 9 | cochrane
# Processing Record 20 of Set 9 | zavodouspenskoye
# Processing Record 21 of Set 9 | gushikawa
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | eirunepe
# Processing Record 24 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 25 of Set 9 | peace river
# Processing Record 26 of Set 9 | pozo colorado
# Processing Record 27 of Set 9 | torbay
# Processing Record 28 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 29 of Set 9 | buin
# Processing Record 30 of Set 9 | tiksi
# Processing Record 31 of Set 9 | vila velha
# Processing Record 32 of Set 9 | cortez
# Processing Record 33 of Set 9 | kargopol
# Processing Record 34 of Set 9 | puri
# Processing Record 35 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 9 | comayagua
# Processing Record 37 of Set 9 | panama city
# Processing Record 38 of Set 9 | qaanaaq
# Processing Record 39 of Set 9 | moron
# Processing Record 40 of Set 9 | epernay
# Processing Record 41 of Set 9 | senno
# Processing Record 42 of Set 9 | kawhia
# Processing Record 43 of Set 9 | kawambwa
# Processing Record 44 of Set 9 | norman wells
# Processing Record 45 of Set 9 | buala
# Processing Record 46 of Set 9 | khash
# Processing Record 47 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 9 | north platte
# Processing Record 49 of Set 9 | thunder bay
# Processing Record 50 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 10 | popondetta
# Processing Record 2 of Set 10 | neuquen
# Processing Record 3 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 10 | ilo
# Processing Record 5 of Set 10 | syracuse
# Processing Record 6 of Set 10 | wentzville
# Processing Record 7 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 10 | mundo nuevo
# Processing Record 9 of Set 10 | victor harbor
# Processing Record 10 of Set 10 | oda
# Processing Record 11 of Set 10 | kaeo
# Processing Record 12 of Set 10 | awjilah
# Processing Record 13 of Set 10 | bagli
# Processing Record 14 of Set 10 | bilma
# Processing Record 15 of Set 10 | loma bonita
# Processing Record 16 of Set 10 | blackwater
# Processing Record 17 of Set 10 | chapais
# Processing Record 18 of Set 10 | katobu
# Processing Record 19 of Set 10 | ruidoso
# Processing Record 20 of Set 10 | seddon
# Processing Record 21 of Set 10 | jiaocheng
# Processing Record 22 of Set 10 | sagua la grande
# Processing Record 23 of Set 10 | sisimiut
# Processing Record 24 of Set 10 | boke
# Processing Record 25 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 10 | san cristobal
# Processing Record 28 of Set 10 | sturgeon falls
# Processing Record 29 of Set 10 | bilibino
# Processing Record 30 of Set 10 | galle
# Processing Record 31 of Set 10 | polyarnyy
# Processing Record 32 of Set 10 | pochutla
# Processing Record 33 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 10 | ouesso
# Processing Record 35 of Set 10 | santo antonio do ica
# Processing Record 36 of Set 10 | tessalit
# Processing Record 37 of Set 10 | carballo
# Processing Record 38 of Set 10 | larsnes
# Processing Record 39 of Set 10 | robertsport
# Processing Record 40 of Set 10 | matipo
# Processing Record 41 of Set 10 | port-gentil
# Processing Record 42 of Set 10 | changji
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 10 | puerto carreno
# Processing Record 46 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 10 | mahajanga
# Processing Record 48 of Set 10 | puerto escondido
# Processing Record 49 of Set 10 | anadyr
# Processing Record 50 of Set 10 | sarangani
# Processing Record 1 of Set 11 | aswan
# Processing Record 2 of Set 11 | rio claro
# Processing Record 3 of Set 11 | kalmunai
# Processing Record 4 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 11 | sechura
# Processing Record 6 of Set 11 | syriam
# Processing Record 7 of Set 11 | sawakin
# Processing Record 8 of Set 11 | diapaga
# Processing Record 9 of Set 11 | walvis bay
# Processing Record 10 of Set 11 | bosaso
# Processing Record 11 of Set 11 | otradnoye
# Processing Record 12 of Set 11 | pacifica
# Processing Record 13 of Set 11 | manzini
# Processing Record 14 of Set 11 | dudinka
# Processing Record 15 of Set 11 | ambilobe
# Processing Record 16 of Set 11 | nara
# Processing Record 17 of Set 11 | tonj
# Processing Record 18 of Set 11 | erdenet
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | ibra
# Processing Record 21 of Set 11 | codrington
# Processing Record 22 of Set 11 | plouzane
# Processing Record 23 of Set 11 | moerai
# Processing Record 24 of Set 11 | okakarara
# Processing Record 25 of Set 11 | novoilinsk
# Processing Record 26 of Set 11 | guerrero negro
# Processing Record 27 of Set 11 | jalu
# Processing Record 28 of Set 11 | soria
# Processing Record 29 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 11 | saint-louis
# Processing Record 31 of Set 11 | dustlik
# Processing Record 32 of Set 11 | lumby
# Processing Record 33 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 34 of Set 11 | necochea
# Processing Record 35 of Set 11 | san rafael
# Processing Record 36 of Set 11 | kurayoshi
# Processing Record 37 of Set 11 | truro
# Processing Record 38 of Set 11 | dibulla
# Processing Record 39 of Set 11 | pirgos
# Processing Record 40 of Set 11 | horta
# Processing Record 41 of Set 11 | bell ville
# Processing Record 42 of Set 11 | talnakh
# Processing Record 43 of Set 11 | asfi
# Processing Record 44 of Set 11 | soligalich
# Processing Record 45 of Set 11 | mithimna
# City not found. Skipping...
# Processing Record 46 of Set 11 | sungaipenuh
# Processing Record 47 of Set 11 | prince george
# Processing Record 48 of Set 11 | teul
# City not found. Skipping...
# Processing Record 49 of Set 11 | kupiskis
# Processing Record 50 of Set 11 | mae hong son
# Processing Record 1 of Set 12 | puerto baquerizo moreno
# Processing Record 2 of Set 12 | crampoaia
# City not found. Skipping...
# Processing Record 3 of Set 12 | clinton
# Processing Record 4 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 12 | shpykiv
# City not found. Skipping...
# Processing Record 6 of Set 12 | sinnamary
# Processing Record 7 of Set 12 | contamana
# Processing Record 8 of Set 12 | yurya
# City not found. Skipping...
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | gravelbourg
# Processing Record 11 of Set 12 | micheweni
# Processing Record 12 of Set 12 | iaciara
# Processing Record 13 of Set 12 | canberra
# Processing Record 14 of Set 12 | sao joao da barra
# Processing Record 15 of Set 12 | shirochanka
# Processing Record 16 of Set 12 | vaasa
# Processing Record 17 of Set 12 | havre
# Processing Record 18 of Set 12 | oranjestad
# Processing Record 19 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 12 | xiangfan
# Processing Record 21 of Set 12 | magadan
# Processing Record 22 of Set 12 | charleston
# Processing Record 23 of Set 12 | wattegama
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | doha
# Processing Record 26 of Set 12 | coahuayana
# Processing Record 27 of Set 12 | constitucion
# Processing Record 28 of Set 12 | estelle
# Processing Record 29 of Set 12 | beloha
# Processing Record 30 of Set 12 | russell
# Processing Record 31 of Set 12 | pedasi
# Processing Record 32 of Set 12 | hays
# Processing Record 33 of Set 12 | penzance
# Processing Record 34 of Set 12 | riberalta
# Processing Record 35 of Set 12 | ostrovnoy
# Processing Record 36 of Set 12 | winder
# Processing Record 37 of Set 12 | yamada
# Processing Record 38 of Set 12 | qingyuan
# Processing Record 39 of Set 12 | djibo
# Processing Record 40 of Set 12 | chiredzi
# Processing Record 41 of Set 12 | flinders
# Processing Record 42 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 12 | nago
# Processing Record 44 of Set 12 | cabedelo
# Processing Record 45 of Set 12 | buraydah
# Processing Record 46 of Set 12 | porangatu
# Processing Record 47 of Set 12 | rockport
# Processing Record 48 of Set 12 | maceio
# Processing Record 49 of Set 12 | fort smith
# Processing Record 50 of Set 12 | sile
# Processing Record 1 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 13 | lazaro cardenas
# Processing Record 3 of Set 13 | sabang
# Processing Record 4 of Set 13 | qaqortoq
# Processing Record 5 of Set 13 | tiwi
# Processing Record 6 of Set 13 | coihaique
# Processing Record 7 of Set 13 | rupert
# Processing Record 8 of Set 13 | adre
# Processing Record 9 of Set 13 | tocache
# Processing Record 10 of Set 13 | kaihua
# Processing Record 11 of Set 13 | axim
# Processing Record 12 of Set 13 | bambanglipuro
# Processing Record 13 of Set 13 | marsh harbour
# Processing Record 14 of Set 13 | maumere
# Processing Record 15 of Set 13 | ornskoldsvik
# Processing Record 16 of Set 13 | naron
# Processing Record 17 of Set 13 | safaqis
# City not found. Skipping...
# Processing Record 18 of Set 13 | hakui
# Processing Record 19 of Set 13 | maarianhamina
# Processing Record 20 of Set 13 | tongliao
# Processing Record 21 of Set 13 | boundiali
# Processing Record 22 of Set 13 | yaremche
# Processing Record 23 of Set 13 | turukhansk
# Processing Record 24 of Set 13 | tornio
# Processing Record 25 of Set 13 | yatou
# Processing Record 26 of Set 13 | nabire
# Processing Record 27 of Set 13 | homer
# Processing Record 28 of Set 13 | pingyi
# Processing Record 29 of Set 13 | honiara
# Processing Record 30 of Set 13 | nautla
# Processing Record 31 of Set 13 | puerto palomas
# Processing Record 32 of Set 13 | moyale
# Processing Record 33 of Set 13 | dandong
# Processing Record 34 of Set 13 | lamu
# Processing Record 35 of Set 13 | chumikan
# Processing Record 36 of Set 13 | naze
# Processing Record 37 of Set 13 | pangody
# Processing Record 38 of Set 13 | trincomalee
# Processing Record 39 of Set 13 | dakoro
# Processing Record 40 of Set 13 | pilar
# Processing Record 41 of Set 13 | komsomolskiy
# Processing Record 42 of Set 13 | velka bites
# Processing Record 43 of Set 13 | pundaguitan
# Processing Record 44 of Set 13 | hailar
# Processing Record 45 of Set 13 | sola
# Processing Record 46 of Set 13 | curico
# Processing Record 47 of Set 13 | alofi
# Processing Record 48 of Set 13 | rossland
# Processing Record 49 of Set 13 | muzhi
# Processing Record 50 of Set 13 | timbiqui
# Processing Record 1 of Set 14 | manokwari
# Processing Record 2 of Set 14 | washougal
# Processing Record 3 of Set 14 | plattling
# Processing Record 4 of Set 14 | sanawad
# Processing Record 5 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 14 | aksu
# Processing Record 7 of Set 14 | ust-maya
# Processing Record 8 of Set 14 | the valley
# Processing Record 9 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 10 of Set 14 | cuilco
# Processing Record 11 of Set 14 | chegdomyn
# Processing Record 12 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 14 | mookane
# Processing Record 14 of Set 14 | yoichi
# Processing Record 15 of Set 14 | bachaquero
# Processing Record 16 of Set 14 | papara
# Processing Record 17 of Set 14 | tulum
# Processing Record 18 of Set 14 | saint-leu
# Processing Record 19 of Set 14 | mpulungu
# Processing Record 20 of Set 14 | bozhou
# Processing Record 21 of Set 14 | seymchan
# Processing Record 22 of Set 14 | saint-pierre
# Processing Record 23 of Set 14 | ponferrada
# Processing Record 24 of Set 14 | abashiri
# Processing Record 25 of Set 14 | milkovo
# Processing Record 26 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 14 | san miguel
# Processing Record 28 of Set 14 | wyndham
# Processing Record 29 of Set 14 | karratha
# Processing Record 30 of Set 14 | ilebo
# Processing Record 31 of Set 14 | bardiyah
# Processing Record 32 of Set 14 | bay roberts
# Processing Record 33 of Set 14 | mataruska banja
# Processing Record 34 of Set 14 | urcos
# Processing Record 35 of Set 14 | cayenne
# Processing Record 36 of Set 14 | bulgan
# Processing Record 37 of Set 14 | ipanguacu
# Processing Record 38 of Set 14 | ewa beach
# Processing Record 39 of Set 14 | sur
# Processing Record 40 of Set 14 | kilemary
# Processing Record 41 of Set 14 | pemangkat
# Processing Record 42 of Set 14 | aviemore
# Processing Record 43 of Set 14 | namtsy
# Processing Record 44 of Set 14 | burica
# City not found. Skipping...
# Processing Record 45 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 14 | salalah
# Processing Record 47 of Set 14 | san quintin
# Processing Record 48 of Set 14 | sadat
# Processing Record 49 of Set 14 | banda aceh
# Processing Record 50 of Set 14 | novyy urengoy
# Processing Record 1 of Set 15 | matamoros
# Processing Record 2 of Set 15 | sakakah
# Processing Record 3 of Set 15 | conde
# Processing Record 4 of Set 15 | tabou
# Processing Record 5 of Set 15 | port lincoln
# Processing Record 6 of Set 15 | quimper
# Processing Record 7 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 15 | lujan
# Processing Record 9 of Set 15 | kifri
# Processing Record 10 of Set 15 | palmer
# Processing Record 11 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 15 | malindi
# Processing Record 13 of Set 15 | mpika
# Processing Record 14 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 15 | hervey bay
# Processing Record 16 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 15 | dwarka
# Processing Record 18 of Set 15 | oltu
# Processing Record 19 of Set 15 | basco
# Processing Record 20 of Set 15 | luba
# Processing Record 21 of Set 15 | husavik
# Processing Record 22 of Set 15 | amberley
# Processing Record 23 of Set 15 | logan
# Processing Record 24 of Set 15 | talaya
# Processing Record 25 of Set 15 | bulungu
# Processing Record 26 of Set 15 | yarmouth
# Processing Record 27 of Set 15 | kirkwall
# Processing Record 28 of Set 15 | elko
# Processing Record 29 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 15 | yumen
# Processing Record 31 of Set 15 | garowe
# Processing Record 32 of Set 15 | bafata
# Processing Record 33 of Set 15 | bridgetown
# Processing Record 34 of Set 15 | westport
# Processing Record 35 of Set 15 | vaisala
# City not found. Skipping...
# Processing Record 36 of Set 15 | winslow
# Processing Record 37 of Set 15 | gizo
# Processing Record 38 of Set 15 | ciudad real
# Processing Record 39 of Set 15 | marihatag
# Processing Record 40 of Set 15 | verkhniy avzyan
# Processing Record 41 of Set 15 | birnin kebbi
# Processing Record 42 of Set 15 | roald
# Processing Record 43 of Set 15 | sanmenxia
# Processing Record 44 of Set 15 | sirineasa
# Processing Record 45 of Set 15 | nizhniy odes
# Processing Record 46 of Set 15 | lianzhou
# Processing Record 47 of Set 15 | asmara
# Processing Record 48 of Set 15 | yar-sale
# Processing Record 49 of Set 15 | matara
# Processing Record 50 of Set 15 | mamallapuram
# Processing Record 1 of Set 16 | port blair
# Processing Record 2 of Set 16 | alice springs
# Processing Record 3 of Set 16 | pierre
# Processing Record 4 of Set 16 | tambun
# Processing Record 5 of Set 16 | diebougou
# Processing Record 6 of Set 16 | manado
# Processing Record 7 of Set 16 | fare
# Processing Record 8 of Set 16 | quelimane
# Processing Record 9 of Set 16 | kollam
# Processing Record 10 of Set 16 | el badari
# City not found. Skipping...
# Processing Record 11 of Set 16 | altea
# Processing Record 12 of Set 16 | labytnangi
# Processing Record 13 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 16 | damietta
# Processing Record 15 of Set 16 | kirensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     73.54        89          72
# 1        Avarua      CK -21.2078 -159.7750     80.65        74          23
# 2      Bengkulu      ID  -3.8004  102.2655     80.98        81          91
# 3        Castro      BR -24.7911  -50.0119     58.26        93          81
# 4        Dingle      PH  10.9995  122.6711     86.92        70          75
# 5  Rapid Valley      US  44.0625 -103.1463     82.60        37           1
# 6     Jamestown      US  42.0970  -79.2353     65.52        92          20
# 7      Beruwala      LK   6.4788   79.9828     80.29        85         100
# 8      Malkapur      IN  20.8833   76.2000     82.99        63          99
# 9       Yenagoa      NG   4.9247    6.2642     76.28        94          88
#
#    Wind Speed Current Description
# 0        5.99       broken clouds
# 1       12.66          few clouds
# 2        1.57     overcast clouds
# 3        3.51       broken clouds
# 4        6.04          light rain
# 5        6.91           clear sky
# 6        3.00          few clouds
# 7       11.18     overcast clouds
# 8        3.69     overcast clouds
# 9        3.33     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
